# %% [markdown]
# <h1><center> 📈Trabalho📈 </center></h1>

# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df_cars = pd.read_csv('dataset/autos.csv', nrows=10000)
limite_superior = 15000
df_cars_filtered = df_cars[df_cars['price'] <= limite_superior]
cars_automatico = df_cars_filtered[df_cars_filtered['gearbox'] == 'automatik']
cars_manual = df_cars_filtered[df_cars_filtered['gearbox'] == 'manuell']

display(df_cars_filtered)
# Out:
#       index          dateCrawled  \
# 0         0  2016-03-24 11:52:17
# 2         2  2016-03-14 12:52:21
# 3         3  2016-03-17 16:54:04
# 4         4  2016-03-31 17:25:20
# 5         5  2016-04-04 17:36:23
# ...     ...                  ...
# 9994   9994  2016-03-09 19:49:38
# 9995   9995  2016-03-26 16:57:43
# 9996   9996  2016-03-20 20:51:42
# 9998   9998  2016-03-28 20:44:11
# 9999   9999  2016-04-01 10:51:16
#
#                                                    name  seller offerType  \
# 0                                            Golf_3_1.6  privat   Angebot
# 2                        Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3                                    GOLF_4_1_4__3TÜRER  privat   Angebot
# 4                        Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 5     BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# ...                                                 ...     ...       ...
# ...

# %% [markdown]
# # Histograma Nominal

# %%
plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
sns.histplot(cars_manual['price'], bins=20, color='skyblue')
plt.title('Distribuição de carros manuais')
plt.xlabel('Preço')
plt.ylabel('Quantidade')
plt.xticks(rotation=50)
plt.subplot(1, 2, 2)
sns.histplot(cars_automatico['price'], bins=20, color='skyblue')
plt.title('Distribuição de carros automaticos')
plt.xlabel('Preço')
plt.ylabel('Quantidade')
plt.xticks(rotation=50)
# Out:
# (array([-2000.,     0.,  2000.,  4000.,  6000.,  8000., 10000., 12000.,
#         14000., 16000.]),
#  [Text(-2000.0, 0, '−2000'),
#   Text(0.0, 0, '0'),
#   Text(2000.0, 0, '2000'),
#   Text(4000.0, 0, '4000'),
#   Text(6000.0, 0, '6000'),
#   Text(8000.0, 0, '8000'),
#   Text(10000.0, 0, '10000'),
#   Text(12000.0, 0, '12000'),
#   Text(14000.0, 0, '14000'),
#   Text(16000.0, 0, '16000')])

# %%
limite_inferior_y = 1990
df_cars_forYear = df_cars_filtered[df_cars_filtered['yearOfRegistration'] >= limite_inferior_y]
px.histogram(data_frame= df_cars_forYear, x="yearOfRegistration", marginal="box", color="model")

# %%
px.histogram(data_frame= df_cars_forYear, x="price", marginal="box", color="model")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 px.histogram(data_frame= df_cars_forYear, x="price", marginal="box", color="model")
#
# NameError: name 'px' is not defined

# %%
# Supondo que você tenha um DataFrame chamado 'df' contendo as informações dos carros, incluindo as colunas 'brand' e 'powerps'

# Agrupando os dados por marca e calculando a média de 'powerps' para cada marca
mean_powerps_by_brand = df_cars_filtered.groupby('brand')['price'].mean()

# Criando o histograma
plt.figure(figsize=(12, 6))
plt.bar(mean_powerps_by_brand.index, mean_powerps_by_brand.values, color='skyblue')
plt.xlabel('Marca')
plt.ylabel('Média de Powerps')
plt.title('Média de Powerps por Marca de Carro')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Geral

# %%
# 1
plt.figure(figsize=(30, 6))
plt.hist(df_cars_filtered['price'], bins=len(df_cars_filtered['price'].unique()), alpha=0.5, edgecolor='black')
plt.xlabel('Marca')
plt.ylabel('Frequência')
plt.title('Histograma de Marcas de Carros')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(45, 10))
plt.subplot(1, 2, 1)
sns.histplot(cars_manual['vehicleType'], bins=20, color='skyblue')
plt.title('Distribuição de carros manuais')
plt.xlabel('Marcas')
plt.ylabel('Quantidade')
plt.xticks(rotation=50)
plt.subplot(1, 2, 2)
sns.histplot(cars_automatico['vehicleType'], bins=20)
plt.title('Distribuição de carros automaticos')
plt.xlabel('Marcas')
plt.ylabel('Quantidade')
plt.xticks(rotation=50)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'suv'),
#   Text(1, 0, 'kleinwagen'),
#   Text(2, 0, 'limousine'),
#   Text(3, 0, 'kombi'),
#   Text(4, 0, 'bus'),
#   Text(5, 0, 'coupe'),
#   Text(6, 0, 'cabrio'),
#   Text(7, 0, 'andere')])

# %% [markdown]
# # Histogramas Númericos

# %%
preco_por_modelo_manual = cars_manual.groupby('brand')['price'].apply(list)
preco_por_modelo_automatico = cars_automatico.groupby('brand')['price'].apply(list)

cars = pd.concat([cars_manual, cars_automatico])

# Plotar um histograma dos preços por marca
plt.figure(figsize=(12, 6))
# for brand, data in cars.groupby('brand'):
plt.hist(df_cars['price'], alpha=0.5, label='price')
plt.xlabel('Preço')
plt.ylabel('Frequência')
plt.title('Histograma de Preço por Marca')
plt.legend()
plt.show()

# %%
# Define os limites dos anos realistas para carros
limite_inferior = 1990
limite_superior = 2020

# Filtra os dados para incluir apenas anos dentro dos limites
df_cars_filtrado = df_cars_filtered[(df_cars_filtered['yearOfRegistration'] >= limite_inferior) & (df_cars_filtered['yearOfRegistration'] <= limite_superior)]

# Plota o histograma com as bordas pretas nas barras
plt.figure(figsize=(12, 6))
plt.hist(df_cars_filtrado['yearOfRegistration'], bins=len(df_cars_filtrado['yearOfRegistration'].unique()), alpha=0.5, edgecolor='black')
plt.xlabel('Ano de Fabricação')
plt.ylabel('Quantidade')
plt.title('Histograma de Ano de Fabricação')
plt.show()

# %%
# Limitar os dados de 1960 a 2020
df_cars_filtered = df_cars[(df_cars['yearOfRegistration'] >= 1965) & (df_cars['yearOfRegistration'] <= 2018)]

# Plotar o histograma com os dados filtrados
fig = px.histogram(data_frame=df_cars_filtered, x="yearOfRegistration", y="price", range_x=[1965, 2018], barmode='overlay',
                   title='Histograma de Ano de Fabricação e Preço',
                   labels={'yearOfRegistration': 'Ano de Fabricação', 'kilometer': 'Kilometro'},
                   opacity=0.75,
                   histnorm='percent',
                   marginal='rug',
                   color_discrete_sequence=['blue'])
fig.update_traces(marker=dict(line=dict(color='black', width=1)))
fig.show()
